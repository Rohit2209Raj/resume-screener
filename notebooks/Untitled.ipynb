# %%
import sys
print(sys.executable)
# Out:
# D:\resume-screener\venv\Scripts\python.exe

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
resume = "Python developer with machine learning experience"
jd = "Hiring Python programmer with ML background"

emb_resume = model.encode(resume)
emb_jd = model.encode(jd)

similarity = util.cos_sim(emb_resume, emb_jd)
print(f"Match Score: {round(float(similarity) * 100, 1)}%")
# Out:
# Match Score: 68.9%
