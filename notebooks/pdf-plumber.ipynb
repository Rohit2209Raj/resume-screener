# %%
# !pip install pdfplumber
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pdfplumber

# %%
with pdfplumber.open(r"D:\resume-screener\test_resume.pdf") as pdf:
    text = pdf.pages[0].extract_text()
    print(text)
# Out:
# ROHIT RAJ Jaipur, Rajasthan | rohit@email.com | github.com/Rohit2209Raj |
# linkedin.com/in/rohitraj
# EDUCATION
# B.Tech — Computer Science Engineering Poornima College of Engineering, Jaipur
# 2024 — 2028 | CGPA: 8.x/10
# SKILLS
# Languages: Python, C++, SQL Libraries/Frameworks: NumPy, Pandas, Matplotlib,
# Seaborn, Scikit-learn, FastAPI AI/ML: Machine Learning, Natural Language Processing,
# Sentence Transformers, spaCy Databases: PostgreSQL, MySQL Tools: Git, GitHub, VS
# Code, Jupyter Notebook, Google Colab, Power BI Concepts: Data Structures &
# Algorithms, OOP, DBMS, REST APIs
# PROJECTS
# AI Resume Screener (Python, FastAPI, Sentence Transformers, spaCy, Streamlit)
# • Built a resume-JD matcher using sentence transformers to compute semantic
# similarity between resume and job description
# • Implemented keyword extraction using spaCy noun chunks to identify missing
# skills
# • Developed REST API using FastAPI with PDF upload support via pdfplumber
# ...

# %%
with pdfplumber.open(r"D:\resume-screener\test_resume.pdf") as pdf:
    all_text=""
    for page in pdf.pages:
        text = page.extract_text()
        if text:
            all_text+=text+'\n'

    print(all_text)
# Out:
# ROHIT RAJ Jaipur, Rajasthan | rohit@email.com | github.com/Rohit2209Raj |
# linkedin.com/in/rohitraj
# EDUCATION
# B.Tech — Computer Science Engineering Poornima College of Engineering, Jaipur
# 2024 — 2028 | CGPA: 8.x/10
# SKILLS
# Languages: Python, C++, SQL Libraries/Frameworks: NumPy, Pandas, Matplotlib,
# Seaborn, Scikit-learn, FastAPI AI/ML: Machine Learning, Natural Language Processing,
# Sentence Transformers, spaCy Databases: PostgreSQL, MySQL Tools: Git, GitHub, VS
# Code, Jupyter Notebook, Google Colab, Power BI Concepts: Data Structures &
# Algorithms, OOP, DBMS, REST APIs
# PROJECTS
# AI Resume Screener (Python, FastAPI, Sentence Transformers, spaCy, Streamlit)
# • Built a resume-JD matcher using sentence transformers to compute semantic
# similarity between resume and job description
# • Implemented keyword extraction using spaCy noun chunks to identify missing
# skills
# • Developed REST API using FastAPI with PDF upload support via pdfplumber
# ...
